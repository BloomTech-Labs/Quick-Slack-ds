# %%
import psycopg2
from sqlalchemy import create_engine
import pandas as pd

# %%
db_string = "postgresql://postgres:postgres@postgres/postgres"
db = create_engine(db_string)

# %%
# Custom notebook magic commands for loading sql.
from IPython.core.magic import register_line_cell_magic
def create_df_sql_magic(magic_name, conn):
  def sql_df(line_query, cell_query=None):
    if cell_query==None:
      return pd.read_sql(line_query, conn)
    return pd.read_sql(cell_query, conn)
  custom_func = sql_df
  custom_func.__name__ = magic_name
  register_line_cell_magic(custom_func)
create_df_sql_magic('sql_df', db)

# %%
# %%sql_df
# SELECT * FROM channel LIMIT 5;

# %%
# %%sql_df
# SELECT * FROM message LIMIT 5;

# %%
# %%sql_df
# SELECT * FROM reply LIMIT 5;

# %%
# %%sql_df
# SELECT * FROM channel where channel_id='CSW4Z94SJ';

# %%
# %%sql_df
# SELECT * FROM reply JOIN channel on reply.channel_id=channel.channel_id LIMIT 10;
# Out:
#    db_id                            message_id    user_id            ts  \
# 0      1  2efa0fb1-68b9-42f5-8c96-4c14aec16f27  UP5UYF6N8  1.579308e+09
# 1      2  c963fe89-2667-4d98-b0f8-10c5554212fb  URR101DRC  1.579308e+09
# 2      3  2eac5b58-97a6-4e63-9e49-1686f5b1fc67  UP5UYF6N8  1.579309e+09
# 3      4  f7450272-9877-4636-ac1e-07b1f33d5528  UL1KZK4S3  1.579284e+09
# 4      5  d2294d89-3268-4438-86e0-07e5febe703b  UL1KZK4S3  1.579284e+09
# 5      6  5b2ca217-9993-46ea-be3e-76ad9848e6d7  UL1KZK4S3  1.579285e+09
# 6      7  cd222f1c-ab60-401c-b9e2-d6e1af12ab9a  US9LR2XSB  1.579486e+09
# 7      8  5af61a25-2f5d-413f-94e8-4f09c7d99200  UPKPTL3E2  1.579486e+09
# 8      9  359a30a8-d136-4dfd-a4c9-2e8cd1b34b65  US9LR2XSB  1.579486e+09
# 9     10  d7907945-d01e-4122-8d83-fa828be977b8  UPKPTL3E2  1.579486e+09
#
#                                                 text     thread_ts channel_id  \
# 0                                        Mas o menos  1.579308e+09  CSW4Z94SJ
# 1                    ¿Qué tanto consideras hablarlo?  1.579308e+09  CSW4Z94SJ
# 2            Buena pregunta. :slightly_smiling_face:  1.579308e+09  CSW4Z94SJ
# 3      <https://www.youtube.com/watch?v=DksSPZTZES0>  1.579284e+09  CSFVA4GP5
# 4                                                     1.579284e+09  CSFVA4GP5
# 5                                                     1.579284e+09  CSFVA4GP5
# 6                                              hello  1.579486e+09  CSRTVGLNQ
# 7                                  <@US9LR2XSB> yes?  1.579486e+09  CSRTVGLNQ
# 8                                     being friendly  1.579486e+09  CSRTVGLNQ
# 9  Awesome. Also can you please schedule a 1:1 wi...  1.579486e+09  CSRTVGLNQ
#
#    db_id channel_id      channel_name
# 0      6  CSW4Z94SJ   learningspanish
# 1      6  CSW4Z94SJ   learningspanish
# 2      6  CSW4Z94SJ   learningspanish
# 3      7  CSFVA4GP5  alternate-lyrics
# 4      7  CSFVA4GP5  alternate-lyrics
# 5      7  CSFVA4GP5  alternate-lyrics
# 6     11  CSRTVGLNQ  dspt5_sun_daniel
# 7     11  CSRTVGLNQ  dspt5_sun_daniel
# 8     11  CSRTVGLNQ  dspt5_sun_daniel
# 9     11  CSRTVGLNQ  dspt5_sun_daniel
